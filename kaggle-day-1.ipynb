# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# %pip install -U -q "google-generativeai>=0.8.3"

# %%
from kaggle_secrets import UserSecretsClient
import google.generativeai as genai
from IPython.display import display, Markdown


user_secrets = UserSecretsClient()
api_key = user_secrets.get_secret("GOOGLE_API_KEY")


genai.configure(api_key=api_key)


flash = genai.GenerativeModel('gemini-1.5-flash')


response = flash.generate_content("Explain AI to me like I'm a kid.")
display(Markdown(response.text))
# Out:
# Imagine you have a really smart friend who loves to learn. This friend can read tons of books, watch lots of videos, and play games all day long. That's kind of like AI, or Artificial Intelligence.
#
# AI is like a computer that can learn just like your friend. It can read lots of information, learn from it, and then use that knowledge to do cool things!
#
# For example, AI can:
#
# * **Help you find the right song to listen to:** It can learn what kind of music you like and suggest new songs you might enjoy.
# * **Translate languages:** It can read words in one language and tell you what they mean in another language.
# * **Play games with you:** It can learn the rules of games and play against you, just like a human friend!
#
# AI is still learning and getting smarter all the time. It's like a baby learning to walk and talk – it's getting better at things every day.
#
# So, AI is a really cool technology that can do lots of amazing things. It's like having a super smart friend that can help you with all sorts of stuff!

# %%
chat = flash.start_chat(history=[])
response = chat.send_message('Hello! My name is Zlork.')
print(response.text)
# Out:
# Hello Zlork! It's nice to meet you. What can I do for you today? 😊

# %%
response = chat.send_message('Can you tell something interesting about dinosaurs?')
print(response.text)
# Out:
# You want something interesting about dinosaurs? Here's a fun fact:
#
# **Did you know that some dinosaurs had feathers?**
#
# That's right! While we often picture dinosaurs as scaly beasts, many species, especially those related to birds, sported feathers. These feathers weren't necessarily for flying, but for insulation, display, or even attracting mates.
#
# This discovery has revolutionized our understanding of dinosaurs and their evolution, and it shows that the line between dinosaurs and birds is not as clear-cut as we once thought!
#
# What else would you like to know about dinosaurs?

# %%
# While you have the `chat` object around, the conversation state
# persists. Confirm that by asking if it knows my name.
response = chat.send_message('Do you remember what my name is?')
print(response.text)
# Out:
# Of course! You're Zlork! 😊 It's nice to have a name to put with your interesting questions about dinosaurs.
#
# Do you have any other questions about these amazing creatures? I'm happy to answer them.

# %%
for model in genai.list_models():
  print(model.name)
# Out:
# models/chat-bison-001
# models/text-bison-001
# models/embedding-gecko-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro
# models/gemini-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-pro-exp-0801
# models/gemini-1.5-pro-exp-0827
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-exp-0827
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924
# models/embedding-001
# models/text-embedding-004
# models/aqa

# %%
for model in genai.list_models():
  if model.name == 'models/gemini-1.5-flash':
    print(model)
    break
# Out:
# Model(name='models/gemini-1.5-flash',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 1.5 Flash',
#       description='Fast and versatile multimodal model for scaling across diverse tasks',
#       input_token_limit=1000000,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)

# %%
short_model = genai.GenerativeModel(
    'gemini-1.5-flash',
    generation_config=genai.GenerationConfig(max_output_tokens=200))

response = short_model.generate_content('Write a 1000 word essay on the importance of olives in modern society.')
print(response.text)
# Out:
# ## The Enduring Appeal of the Olive: A Culinary and Cultural Icon in Modern Society
#
# The humble olive, a small, unassuming fruit, holds a significance that far surpasses its size and appearance. From ancient civilizations to modern kitchens, the olive has played a vital role in shaping human culture, cuisine, and even health. Its enduring appeal lies in its versatility, nutritional value, and symbolic representation, making it an integral part of modern society.
#
# Firstly, the olive's culinary versatility is unmatched. Its rich history as a food source is evident in its widespread use across various cuisines. From the Mediterranean, where it is a cornerstone of traditional dishes, to modern fusion cooking, the olive's unique flavor profile, ranging from briny and earthy to buttery and peppery, adds depth and complexity to countless recipes.
#
# Olive oil, extracted from the fruit, is a culinary staple celebrated for its flavor and health benefits. Its high smoke point makes it ideal for cooking, while its monouns

# %%
short_model = genai.GenerativeModel(
    'gemini-1.5-flash',
    generation_config=genai.GenerationConfig(max_output_tokens=200))

response = short_model.generate_content('Write a 1000 word essay on the importance of olives in modern society.')
print(response.text)
# Out:
# ## More Than Just a Snack: The Enduring Significance of Olives in Modern Society
#
# Olives, those wrinkled, briny treasures, have a history as rich and complex as their flavor. From their ancient origins in the Mediterranean basin to their widespread presence on modern tables across the globe, olives have played a pivotal role in human history and continue to hold a significant place in our society today. This essay explores the multifaceted importance of olives in modern society, examining their cultural, economic, health, and environmental significance.
#
# **A Culinary Icon:** Olives, in their various forms, have long been a staple food in many cultures. From the simple, salty olives enjoyed in their natural state to the more elaborate, marinated and stuffed varieties, olives offer a unique flavor profile that adds depth and complexity to countless dishes. Their versatility extends beyond savory cuisine, as olives are also incorporated into desserts, cocktails, and even ice cream, showcasing their adaptability and enduring popularity.
#
# **A Cultural Symbol:** Olives are deeply intertwined

# %%
import time

high_temp_model = genai.GenerativeModel(
    'gemini-1.5-flash',
    generation_config=genai.GenerationConfig(temperature=2.0))

for _ in range(3):
  response = high_temp_model.generate_content('Pick a random colour... (answer in a single word)')
  if response.parts:
    print(response.text, '-' * 25)

 
  time.sleep(10)
# Out:
# Purple.
#  -------------------------
# Purple
#  -------------------------
# Blue
#  -------------------------

# %%
low_temp_model = genai.GenerativeModel(
    'gemini-1.5-flash',
    generation_config=genai.GenerationConfig(temperature=0.0))

for _ in range(4):
  response = low_temp_model.generate_content('Pick a random colour... (answer in a single word)')
  if response.parts:
    print(response.text, '-' * 25)

  time.sleep(10)
# Out:
# ---------------------------------------------------------------------------
# ResourceExhausted                         Traceback (most recent call last)
# Cell In[18], line 6
#       1 low_temp_model = genai.GenerativeModel(
#       2     'gemini-1.5-flash',
#       3     generation_config=genai.GenerationConfig(temperature=0.0))
#       5 for _ in range(4):
# ----> 6   response = low_temp_model.generate_content('Pick a random colour... (answer in a single word)')
#       7   if response.parts:
#       8     print(response.text, '-' * 25)
#
# File /opt/conda/lib/python3.10/site-packages/google/generativeai/generative_models.py:331, in GenerativeModel.generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329         return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330     else:
# --> 331         response = self._client.generate_content(
#     332             request,
#     333             **request_options,
#     334         )
#     335         return generation_types.GenerateContentResponse.from_response(response)
#     336 except google.api_core.exceptions.InvalidArgument as e:
#
# File /opt/conda/lib/python3.10/site-packages/google/generativeai/client.py:267, in _ClientManager.make_client.<locals>.add_default_metadata_wrapper.<locals>.call(metadata, *args, **kwargs)
#     265 def call(*args, metadata=(), **kwargs):
#     266     metadata = list(metadata) + list(self.default_metadata)
# --> 267     return f(*args, **kwargs, metadata=metadata)
#
# File /opt/conda/lib/python3.10/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py:830, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     827 self._validate_universe_domain()
#     829 # Send the request.
# --> 830 response = rpc(
#     831     request,
#     832     retry=retry,
#     833     timeout=timeout,
#     834     metadata=metadata,
#     835 )
#     837 # Done; return the response.
#     838 return response
#
# File /opt/conda/lib/python3.10/site-packages/google/api_core/gapic_v1/method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py:293, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     289 target = functools.partial(func, *args, **kwargs)
#     290 sleep_generator = exponential_sleep_generator(
#     291     self._initial, self._maximum, multiplier=self._multiplier
#     292 )
# --> 293 return retry_target(
#     294     target,
#     295     self._predicate,
#     296     sleep_generator,
#     297     timeout=self._timeout,
#     298     on_error=on_error,
#     299 )
#
# File /opt/conda/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py:153, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     149 # pylint: disable=broad-except
#     150 # This function explicitly must deal with broad exceptions.
#     151 except Exception as exc:
#     152     # defer to shared logic for handling errors
# --> 153     _retry_error_helper(
#     154         exc,
#     155         deadline,
#     156         sleep,
#     157         error_list,
#     158         predicate,
#     159         on_error,
#     160         exception_factory,
#     161         timeout,
#     162     )
#     163     # if exception not raised, sleep before next attempt
#     164     time.sleep(sleep)
#
# File /opt/conda/lib/python3.10/site-packages/google/api_core/retry/retry_base.py:212, in _retry_error_helper(exc, deadline, next_sleep, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     206 if not predicate_fn(exc):
#     207     final_exc, source_exc = exc_factory_fn(
#     208         error_list,
#     209         RetryFailureReason.NON_RETRYABLE_ERROR,
#     210         original_timeout,
#     211     )
# --> 212     raise final_exc from source_exc
#     213 if on_error_fn is not None:
#     214     on_error_fn(exc)
#
# File /opt/conda/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py:144, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     142 for sleep in sleep_generator:
#     143     try:
# --> 144         result = target()
#     145         if inspect.isawaitable(result):
#     146             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File /opt/conda/lib/python3.10/site-packages/google/api_core/timeout.py:120, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     117     # Avoid setting negative timeout
#     118     kwargs["timeout"] = max(0, self._timeout - time_since_first_attempt)
# --> 120 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/google/api_core/grpc_helpers.py:78, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      76     return callable_(*args, **kwargs)
#      77 except grpc.RpcError as exc:
# ---> 78     raise exceptions.from_grpc_error(exc) from exc
#
# ResourceExhausted: 429 Resource has been exhausted (e.g. check quota).

# %%
model = genai.GenerativeModel(
    'gemini-1.5-flash-001',
    generation_config=genai.GenerationConfig(
        # These are the default values for gemini-1.5-flash-001.
        temperature=1.0,
        top_k=64,
        top_p=0.95,
    ))

story_prompt = "You are a creative writer. Write a short story about a cat who goes on an adventure."
response = model.generate_content(story_prompt)
print(response.text)
# Out:
# Whiskers twitched, tail swished, Mittens felt the familiar thrill of the hunt. A plump, unsuspecting robin hopped on the lawn, unaware of the green-eyed predator lurking in the shadows. But Mittens wasn't interested in the bird. Her gaze was fixed on something beyond the robin, something shimmering in the sunlight, a glint of gold on the other side of the fence.
#
# The fence was a formidable obstacle, an impassable wall to most cats, but not to Mittens. With a practiced leap, she cleared it in a single bound, landing gracefully on the other side. The object of her fascination was a small, golden key, lying abandoned on the dew-kissed grass.
#
# Mittens nudged it with her nose, a curious scent clinging to its smooth surface. An irresistible urge to explore took hold.  She followed the scent, leading her through a maze of overgrown gardens, past rusting metal sheds, and finally, to an ancient, moss-covered stone door.
#
# The key fit perfectly in the lock. With a click, the door swung open, revealing a hidden world. Sunlight streamed through stained glass windows, illuminating dusty shelves lined with leather-bound books and antique toys. It was a wonderland for a curious feline.
#
# Mittens spent the next hour exploring the forgotten attic, her paws padding over cobwebs and her nose sniffing out secrets hidden in forgotten corners. She discovered a dusty, leather-bound book filled with hand-drawn maps and cryptic symbols. A map, she realised, leading to a secret treasure.
#
# An adventurous spirit surged within her. She followed the map, her sharp claws navigating the twisting corridors of the house, leading her to a hidden room behind a secret bookshelf. There, under a faded tapestry, lay a wooden chest, its surface intricately carved with fantastical creatures. The key, once again, fitted perfectly.
#
# The chest creaked open, revealing a treasure trove of sparkling jewels and golden coins.  Mittens, however, wasn't interested in wealth.  She was drawn to a small, tarnished locket, tucked beneath the jewels. She nudged it open, revealing a faded photograph of a little girl, with a mischievous glint in her eye, identical to her own.
#
# Mittens knew then, this wasn't just a forgotten treasure, but a lost piece of someone's past. She curled up next to the locket, a warmth spreading through her chest.  The key, the map, the treasure - all of it was a reminder that even the smallest creature, with a little curiosity and a lot of heart, could embark on grand adventures and discover something far more valuable than gold.
#
# As the sun began to set, casting long shadows through the attic window, Mittens knew it was time to return home. She left the locket nestled beside the photograph, leaving the treasure where it belonged. With a final lick of her paw, she closed the chest and slipped out of the attic, the golden key dangling from her collar, a memento of her extraordinary adventure.  The world outside, bathed in the golden glow of the setting sun, seemed even more familiar, even more beautiful, after her journey into the unknown. And Mittens knew, with a purr of contentment, that her life, just like the key on her collar, held countless adventures waiting to be unlocked.

# %%
# Prompting
# This section contains some prompts to try out directly in the API. 
# Try changing the text here to see how each prompt performs with different instructions,
# more examples, or any other changes you can think of.

model = genai.GenerativeModel(
    'gemini-1.5-flash-001',
    generation_config=genai.GenerationConfig(
        temperature=0.1,
        top_p=1,
        max_output_tokens=5,
    ))

zero_shot_prompt = """Classify movie reviews as POSITIVE, NEUTRAL or NEGATIVE.
Review: "Her" is a disturbing study revealing the direction
humanity is headed if AI is allowed to keep evolving,
unchecked. I wish there were more movies like this masterpiece.
Sentiment: """

response = model.generate_content(zero_shot_prompt)
print(response.text)

# %%
# The Gemini API has an Enum mode feature that allows you to constrain the output to a fixed set of values.
import enum

class Sentiment(enum.Enum):
    POSITIVE = "positive"
    NEUTRAL = "neutral"
    NEGATIVE = "negative"


model = genai.GenerativeModel(
    'gemini-1.5-flash-001',
    generation_config=genai.GenerationConfig(
        response_mime_type="text/x.enum",
        response_schema=Sentiment
    ))

response = model.generate_content(zero_shot_prompt)
print(response.text)

# %%
# One-shot and few-shot¶
# Providing an example of the expected response is known as a "one-shot" prompt.
# When you provide multiple examples, it is a "few-shot" prompt.

model = genai.GenerativeModel(
    'gemini-1.5-flash-latest',
    generation_config=genai.GenerationConfig(
        temperature=0.1,
        top_p=1,
        max_output_tokens=250,
    ))

few_shot_prompt = """Parse a customer's pizza order into valid JSON:

EXAMPLE:
I want a small spicy pizza with cheese, tomato sauce, and pepperoni.
JSON Response:
```
{
"size": "small",
"type": "spicy",
"ingredients": ["cheese", "tomato sauce", "peperoni"]
}
```

EXAMPLE:
Can I get a large pizza with tomato sauce, basil and mozzarella
JSON Response:
```
{
"size": "large",
"type": "normal",
"ingredients": ["tomato sauce", "basil", "mozzarella"]
}

ORDER:
"""

customer_order = "Give me a large spicy with cheese & pineapple"


response = model.generate_content([few_shot_prompt, customer_order])
print(response.text)
# Out:
# ```json
# {
# "size": "large",
# "type": "spicy",
# "ingredients": ["cheese", "pineapple"]
# }
# ```

# %%
# This forces the model to constrain decoding, such that token selection is guided by the supplied schema.
# 
import typing_extensions as typing

class PizzaOrder(typing.TypedDict):
    size: str
    ingredients: list[str]
    type: str


model = genai.GenerativeModel(
    'gemini-1.5-flash-latest',
    generation_config=genai.GenerationConfig(
        temperature=0.1,
        response_mime_type="application/json",
        response_schema=PizzaOrder,
    ))

response = model.generate_content("Can I have a large dessert pizza with apple and chocolate")
print(response.text)
# Out:
# {"ingredients": ["apple", "chocolate"], "size": "large", "type": "dessert"}

# %%
# Chain-of-Thought prompting is a technique where you instruct the model to output intermediate reasoning
# steps, and it typically gets better results, especially when combined with few-shot examples.
# It is worth noting that this technique doesn't completely eliminate hallucinations,
# and that it tends to cost more to run, due to the increased token count.

prompt = """When I was 4 years old, my partner was 3 times my age. Now, I
am 20 years old. How old is my partner? Return the answer immediately."""

model = genai.GenerativeModel('gemini-1.5-flash-latest')
response = model.generate_content(prompt)

print(response.text)
# Out:
# Here's how to solve this:
#
# * **When you were 4, your partner was 3 times your age:** 4 * 3 = 12 years old
# * **Age difference:** Your partner is 12 - 4 = 8 years older than you.
# * **Now you are 20, so your partner is:** 20 + 8 = **28 years old**

# %%
#run a ReAct prompt directly in the Gemini API and perform the searching steps yourself. 
#As this prompt follows a well-defined structure, there are frameworks available that wrap the prompt into easier-to-use APIs that make tool calls automatically, 
#such as the LangChain example from the chapter

model_instructions = """
Solve a question answering task with interleaving Thought, Action, Observation steps. Thought can reason about the current situation,
Observation is understanding relevant information from an Action's output and Action can be one of three types:
 (1) <search>entity</search>, which searches the exact entity on Wikipedia and returns the first paragraph if it exists. If not, it
     will return some similar entities to search and you can try to search the information from those topics.
 (2) <lookup>keyword</lookup>, which returns the next sentence containing keyword in the current context. This only does exact matches,
     so keep your searches short.
 (3) <finish>answer</finish>, which returns the answer and finishes the task.
"""

example1 = """Question
Musician and satirist Allie Goertz wrote a song about the "The Simpsons" character Milhouse, who Matt Groening named after who?

Thought 1
The question simplifies to "The Simpsons" character Milhouse is named after who. I only need to search Milhouse and find who it is named after.

Action 1
<search>Milhouse</search>

Observation 1
Milhouse Mussolini Van Houten is a recurring character in the Fox animated television series The Simpsons voiced by Pamela Hayden and created by Matt Groening.

Thought 2
The paragraph does not tell who Milhouse is named after, maybe I can look up "named after".

Action 2
<lookup>named after</lookup>

Observation 2
Milhouse was named after U.S. president Richard Nixon, whose middle name was Milhous.

Thought 3
Milhouse was named after U.S. president Richard Nixon, so the answer is Richard Nixon.

Action 3
<finish>Richard Nixon</finish>
"""

example2 = """Question
What is the elevation range for the area that the eastern sector of the Colorado orogeny extends into?

Thought 1
I need to search Colorado orogeny, find the area that the eastern sector of the Colorado orogeny extends into, then find the elevation range of the area.

Action 1
<search>Colorado orogeny</search>

Observation 1
The Colorado orogeny was an episode of mountain building (an orogeny) in Colorado and surrounding areas.

Thought 2
It does not mention the eastern sector. So I need to look up eastern sector.

Action 2
<lookup>eastern sector</lookup>

Observation 2
The eastern sector extends into the High Plains and is called the Central Plains orogeny.

Thought 3
The eastern sector of Colorado orogeny extends into the High Plains. So I need to search High Plains and find its elevation range.

Action 3
<search>High Plains</search>

Observation 3
High Plains refers to one of two distinct land regions

Thought 4
I need to instead search High Plains (United States).

Action 4
<search>High Plains (United States)</search>

Observation 4
The High Plains are a subregion of the Great Plains. From east to west, the High Plains rise in elevation from around 1,800 to 7,000 ft (550 to 2,130m).

Thought 5
High Plains rise in elevation from around 1,800 to 7,000 ft, so the answer is 1,800 to 7,000 ft.

Action 5
<finish>1,800 to 7,000 ft</finish>."""

# %%
question = """Question
Who was the youngest author listed on the transformers NLP paper?
"""

model = genai.GenerativeModel('gemini-1.5-flash-latest')
react_chat = model.start_chat()

# You will perform the Action, so generate up to, but not including, the Observation.
config = genai.GenerationConfig(stop_sequences=["\nObservation"])

resp = react_chat.send_message(
    [model_instructions, example1, example2, question],
    generation_config=config)
print(resp.text)
# Out:
# Thought 1
# I need to search for the Transformers paper and find the authors. Then I need to figure out who the youngest is.
#
# Action 1
# <search>Transformers paper</search>

# %%
observation = """Observation 1
[1706.03762] Attention Is All You Need
Ashish Vaswani, Noam Shazeer, Niki Parmar, Jakob Uszkoreit, Llion Jones, Aidan N. Gomez, Lukasz Kaiser, Illia Polosukhin
We propose a new simple network architecture, the Transformer, based solely on attention mechanisms, dispensing with recurrence and convolutions entirely.
"""
resp = react_chat.send_message(observation, generation_config=config)
print(resp.text)
# Out:
# Thought 2
# The observation does not have information on the age of authors. I will search for a different version of the paper.
#
# Action 2
# <search>Transformers paper (NLP)</search>

# %%
# Code prompting¶
# Generating code
# The Gemini family of models can be used to generate code, configuration and scripts. Generating code can be helpful when learning to code,
# learning a new language or for rapidly generating a first draft.
file_contents = !curl https://raw.githubusercontent.com/magicmonty/bash-git-prompt/refs/heads/master/gitprompt.sh

explain_prompt = f"""
Please explain what this file does at a very high level. What is it, and why would I use it?

```
{file_contents}
```
"""

model = genai.GenerativeModel('gemini-1.5-flash-latest')

response = model.generate_content(explain_prompt)
Markdown(response.text)
# Out:
# This file is a Bash script that provides a customized Git prompt for your terminal. It aims to enhance the default Git prompt by displaying more detailed information about your current Git repository.
#
# Here's a breakdown of its key functionalities:
#
# * **Color Themes:** It offers various color themes to customize the appearance of your Git prompt, allowing you to choose from pre-defined themes or create your own custom theme.
# * **Branch Information:** It displays your current branch name, along with indicators like "ahead" or "behind" if your local branch is out of sync with the remote.
# * **Status Indicators:** It provides visual cues for various Git states like staged changes, conflicts, untracked files, stashed changes, and more.
# * **Upstream Tracking:**  It can show information about your branch's tracking status, including how many commits you're ahead or behind.
# * **Remote URL Display:** It allows you to include the remote URL in the prompt, providing a more informative overview of your project.
# * **Virtual Environment Support:** It can integrate with virtual environments (like Python's virtualenv, Node's nvm, and Conda) to display the active environment in the prompt.
# * **Prompt Customization:**  It provides options to customize the prompt's appearance, including adding symbols, changing the order of elements, and controlling the display of certain information.
#
# **Why use it?**
#
# * **Improved Git Visibility:** The script enhances the basic Git prompt with more detailed information, giving you a clearer picture of your repository's state.
# * **Enhanced Workflow:**  The prompt helps you quickly identify the branch you're working on, see the status of your changes, and spot potential issues.
# * **Visual Organization:** Color themes and customization options make the prompt more visually appealing and easier to read.
# * **Efficiency:** By displaying important Git information in the prompt, you can save time by avoiding unnecessary commands.
#
# **To use it:**
#
# 1. **Copy the script:** Save the code to a file named `bash-git-prompt.sh` in your preferred location.
# 2. **Make it executable:** Run `chmod +x bash-git-prompt.sh`.
# 3. **Source it in your shell:** Add the following line to your `~/.bashrc` or `~/.zshrc` file:
#    ```bash
#    source /path/to/bash-git-prompt.sh
#    ```
# 4. **Reload your shell:** Close and reopen your terminal or run `source ~/.bashrc` or `source ~/.zshrc`.
#
# Now, when you open a new terminal window or shell, you should see a more detailed Git prompt reflecting your repository's status.
